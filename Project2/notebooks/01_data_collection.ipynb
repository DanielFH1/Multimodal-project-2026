# %% [markdown]
# # 🎵 Phase 2: Data Collection
#
# ## Objectives
# - Connect to Spotify API
# - Collect artist metadata and audio features
# - Download album cover images
# - Gather social media engagement metrics
#
# ## Data Sources
# 1. **Spotify API**: Track features, artist info, popularity scores
# 2. **Album Covers**: Visual data for CNN analysis
# 3. **Public Datasets**: Chart positions, streaming counts

# %%
# Setup
import pandas as pd
import numpy as np
import requests
from tqdm import tqdm

print('📦 Libraries loaded successfully!')

# %% [markdown]
# ## TODO: Phase 2에서 작성 예정
# - [ ] API 연동 코드
# - [ ] 데이터 수집 함수
# - [ ] 이미지 다운로드 로직
